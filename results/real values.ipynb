# %%
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %%
original = pd.read_csv(r'..\..\datasets\nfs_cleaned_most_common_ncm.csv', encoding='latin-1')

iforest = pd.read_csv(r'..\iforest\output\outliers.csv', encoding='latin-1')
iforest = iforest['idx']

som = pd.read_csv(r'..\som\output\outliers.csv', encoding='latin-1')
som = som['idx']

lof = pd.read_csv(r'..\lof\output\outliers.csv', encoding='latin-1')
lof = lof['idx']

intersec1 = pd.read_csv(r'output\som_iforest_intersec.csv', encoding='latin-1')
intersec1 = intersec1['idx']

intersec2 = pd.read_csv(r'output\som_lof_intersec.csv', encoding='latin-1')
intersec2 = intersec2['idx']

intersec3 = pd.read_csv(r'output\lof_iforest_intersec.csv', encoding='latin-1')
intersec3 = intersec3['idx']

intersec4 = pd.read_csv(r'output\all_intersec.csv', encoding='latin-1')
intersec4 = intersec4['idx']

# %%
iforest_rows = original.loc[iforest]
iforest_rows['idx'] = iforest_rows.index
iforest_rows.to_csv(r'output\iforest_real_values.csv', encoding='utf-8', index=False)
iforest_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 764 entries, 71964 to 55970
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nf_numero         764 non-null    int64
#  1   nf_item           764 non-null    int64
#  2   nf_datahora       764 non-null    object
#  3   nf_timestamp      764 non-null    int64
#  4   nf_valor_total    764 non-null    float64
#  5   emit_nome         764 non-null    object
#  6   emit_cnpj         764 non-null    int64
#  7   emit_bairro       764 non-null    object
#  8   emit_municipio    764 non-null    object
#  9   emit_cep          764 non-null    int64
#  10  emit_lat          764 non-null    float64
#  11  emit_long         764 non-null    float64
#  12  prod_desc         764 non-null    object
#  13  prod_ncm          764 non-null    int64
#  14  prod_cfop         764 non-null    int64
#  15  prod_quant        764 non-null    float64
#  16  prod_unid         764 non-null    object
#  17  prod_valor_unit   764 non-null    float64
#  18  prod_valor_total  764 non-null    float64
#  19  idx               764 non-null    int64
# dtypes: float64(6), int64(8), object(6)
# memory usage: 125.3+ KB

# %%
som_rows = original.loc[som]
som_rows['idx'] = som_rows.index
som_rows.to_csv(r'output\som_real_values.csv', encoding='utf-8', index=False)
som_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 765 entries, 70971 to 55230
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nf_numero         765 non-null    int64
#  1   nf_item           765 non-null    int64
#  2   nf_datahora       765 non-null    object
#  3   nf_timestamp      765 non-null    int64
#  4   nf_valor_total    765 non-null    float64
#  5   emit_nome         765 non-null    object
#  6   emit_cnpj         765 non-null    int64
#  7   emit_bairro       765 non-null    object
#  8   emit_municipio    765 non-null    object
#  9   emit_cep          765 non-null    int64
#  10  emit_lat          765 non-null    float64
#  11  emit_long         765 non-null    float64
#  12  prod_desc         765 non-null    object
#  13  prod_ncm          765 non-null    int64
#  14  prod_cfop         765 non-null    int64
#  15  prod_quant        765 non-null    float64
#  16  prod_unid         765 non-null    object
#  17  prod_valor_unit   765 non-null    float64
#  18  prod_valor_total  765 non-null    float64
#  19  idx               765 non-null    int64
# dtypes: float64(6), int64(8), object(6)
# memory usage: 125.5+ KB

# %%
lof_rows = original.loc[lof]
lof_rows['idx'] = lof_rows.index
lof_rows.to_csv(r'output\lof_real_values.csv', encoding='utf-8', index=False)
lof_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 765 entries, 72126 to 62034
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nf_numero         765 non-null    int64
#  1   nf_item           765 non-null    int64
#  2   nf_datahora       765 non-null    object
#  3   nf_timestamp      765 non-null    int64
#  4   nf_valor_total    765 non-null    float64
#  5   emit_nome         765 non-null    object
#  6   emit_cnpj         765 non-null    int64
#  7   emit_bairro       765 non-null    object
#  8   emit_municipio    765 non-null    object
#  9   emit_cep          765 non-null    int64
#  10  emit_lat          765 non-null    float64
#  11  emit_long         765 non-null    float64
#  12  prod_desc         765 non-null    object
#  13  prod_ncm          765 non-null    int64
#  14  prod_cfop         765 non-null    int64
#  15  prod_quant        765 non-null    float64
#  16  prod_unid         765 non-null    object
#  17  prod_valor_unit   765 non-null    float64
#  18  prod_valor_total  765 non-null    float64
#  19  idx               765 non-null    int64
# dtypes: float64(6), int64(8), object(6)
# memory usage: 125.5+ KB

# %%
intersec1 = original.loc[intersec1]
intersec1['idx'] = intersec1.index
intersec1.to_csv(r'output\som_iforest_real_values.csv', encoding='utf-8', index=False)
intersec1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 218 entries, 46592 to 46591
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nf_numero         218 non-null    int64
#  1   nf_item           218 non-null    int64
#  2   nf_datahora       218 non-null    object
#  3   nf_timestamp      218 non-null    int64
#  4   nf_valor_total    218 non-null    float64
#  5   emit_nome         218 non-null    object
#  6   emit_cnpj         218 non-null    int64
#  7   emit_bairro       218 non-null    object
#  8   emit_municipio    218 non-null    object
#  9   emit_cep          218 non-null    int64
#  10  emit_lat          218 non-null    float64
#  11  emit_long         218 non-null    float64
#  12  prod_desc         218 non-null    object
#  13  prod_ncm          218 non-null    int64
#  14  prod_cfop         218 non-null    int64
#  15  prod_quant        218 non-null    float64
#  16  prod_unid         218 non-null    object
#  17  prod_valor_unit   218 non-null    float64
#  18  prod_valor_total  218 non-null    float64
#  19  idx               218 non-null    int64
# dtypes: float64(6), int64(8), object(6)
# memory usage: 35.8+ KB

# %%
intersec2 = original.loc[intersec2]
intersec2['idx'] = intersec2.index
intersec2.to_csv(r'output\som_lof_real_values.csv', encoding='utf-8', index=False)
intersec2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 76293 to 74235
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nf_numero         103 non-null    int64
#  1   nf_item           103 non-null    int64
#  2   nf_datahora       103 non-null    object
#  3   nf_timestamp      103 non-null    int64
#  4   nf_valor_total    103 non-null    float64
#  5   emit_nome         103 non-null    object
#  6   emit_cnpj         103 non-null    int64
#  7   emit_bairro       103 non-null    object
#  8   emit_municipio    103 non-null    object
#  9   emit_cep          103 non-null    int64
#  10  emit_lat          103 non-null    float64
#  11  emit_long         103 non-null    float64
#  12  prod_desc         103 non-null    object
#  13  prod_ncm          103 non-null    int64
#  14  prod_cfop         103 non-null    int64
#  15  prod_quant        103 non-null    float64
#  16  prod_unid         103 non-null    object
#  17  prod_valor_unit   103 non-null    float64
#  18  prod_valor_total  103 non-null    float64
#  19  idx               103 non-null    int64
# dtypes: float64(6), int64(8), object(6)
# memory usage: 16.9+ KB

# %%
intersec3 = original.loc[intersec3]
intersec3['idx'] = intersec3.index
intersec3.to_csv(r'output\lof_iforest_real_values.csv', encoding='utf-8', index=False)
intersec3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 72194 to 72187
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nf_numero         38 non-null     int64
#  1   nf_item           38 non-null     int64
#  2   nf_datahora       38 non-null     object
#  3   nf_timestamp      38 non-null     int64
#  4   nf_valor_total    38 non-null     float64
#  5   emit_nome         38 non-null     object
#  6   emit_cnpj         38 non-null     int64
#  7   emit_bairro       38 non-null     object
#  8   emit_municipio    38 non-null     object
#  9   emit_cep          38 non-null     int64
#  10  emit_lat          38 non-null     float64
#  11  emit_long         38 non-null     float64
#  12  prod_desc         38 non-null     object
#  13  prod_ncm          38 non-null     int64
#  14  prod_cfop         38 non-null     int64
#  15  prod_quant        38 non-null     float64
#  16  prod_unid         38 non-null     object
#  17  prod_valor_unit   38 non-null     float64
#  18  prod_valor_total  38 non-null     float64
#  19  idx               38 non-null     int64
# dtypes: float64(6), int64(8), object(6)
# memory usage: 6.2+ KB

# %%
intersec4 = original.loc[intersec4]
intersec4['idx'] = intersec4.index
intersec4.to_csv(r'output\all_intersec_real_values.csv', encoding='utf-8', index=False)
intersec4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 71968 to 70971
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nf_numero         15 non-null     int64
#  1   nf_item           15 non-null     int64
#  2   nf_datahora       15 non-null     object
#  3   nf_timestamp      15 non-null     int64
#  4   nf_valor_total    15 non-null     float64
#  5   emit_nome         15 non-null     object
#  6   emit_cnpj         15 non-null     int64
#  7   emit_bairro       15 non-null     object
#  8   emit_municipio    15 non-null     object
#  9   emit_cep          15 non-null     int64
#  10  emit_lat          15 non-null     float64
#  11  emit_long         15 non-null     float64
#  12  prod_desc         15 non-null     object
#  13  prod_ncm          15 non-null     int64
#  14  prod_cfop         15 non-null     int64
#  15  prod_quant        15 non-null     float64
#  16  prod_unid         15 non-null     object
#  17  prod_valor_unit   15 non-null     float64
#  18  prod_valor_total  15 non-null     float64
#  19  idx               15 non-null     int64
# dtypes: float64(6), int64(8), object(6)
# memory usage: 2.5+ KB

# %%
query = original[original['prod_desc'].str.contains('simeticona', case=False) & (original['prod_unid'] == 'cp')]
query
# Out:
#        nf_numero  nf_item          nf_datahora  nf_timestamp  nf_valor_total  \
# 11150        857       11  2016-03-17 16:17:17    1458231437        27249.41
# 17878      15747        3  2016-11-22 17:25:55    1479835555         4714.50
# 39530       3402       19  2016-01-06 00:00:00    1452038400         2304.96
# 47885       3412       42  2016-02-05 00:00:00    1454630400         9546.77
# 48046       3560       92  2016-03-12 00:00:00    1457740800        11892.35
# 48068       3911       10  2016-05-25 00:00:00    1464134400         4983.98
# 48076       3911       33  2016-05-25 00:00:00    1464134400         4983.98
# 48185        156       92  2016-03-14 00:00:00    1457913600        11892.35
# 48408        154       42  2016-02-11 00:00:00    1455148800         9546.77
# 48838       3881       45  2016-05-19 00:00:00    1463616000        17114.46
# 48981       3724        8  2016-04-15 00:00:00    1460678400         3540.60
# 76294     443067        2  2016-08-29 18:13:48    1472494428           60.00
# 76295     443070        3  2016-08-29 18:14:16    1472494456          228.00
# 76296     443325        3  2016-08-30 15:55:25    1472572525          766.00
# 76297     443326        3  2016-08-30 15:55:45    1472572545          766.00
# 76298     443023        1  2016-08-29 17:26:54    1472491614         1722.00
# 76299     443024        3  2016-08-29 17:27:08    1472491628          190.00
# 76300     443025        1  2016-08-29 17:27:21    1472491641          336.00
#
#                                              emit_nome       emit_cnpj  \
# 11150             mm comercial de medicamentos ltda me  13312369000181
# 17878                       medfarmacy hospitalar ltda  10806118000165
# 39530                  distribuidora salutte ltda - me   9193047000193
# 47885  dismene distr. de medicamentos do nordeste ltda  16682179000144
# 48046  dismene distr. de medicamentos do nordeste ltda  16682179000144
# 48068  dismene distr. de medicamentos do nordeste ltda  16682179000144
# 48076  dismene distr. de medicamentos do nordeste ltda  16682179000144
# 48185  dismene distr. de medicamentos do nordeste ltda  16682179000144
# 48408  dismene distr. de medicamentos do nordeste ltda  16682179000144
# 48838  dismene distr. de medicamentos do nordeste ltda  16682179000144
# 48981  dismene distr. de medicamentos do nordeste ltda  16682179000144
# 76294                       prati,donaduzzi e cia ltda  73856593000166
# 76295                       prati,donaduzzi e cia ltda  73856593000166
# 76296                       prati,donaduzzi e cia ltda  73856593000166
# 76297                       prati,donaduzzi e cia ltda  73856593000166
# 76298                       prati,donaduzzi e cia ltda  73856593000166
# 76299                       prati,donaduzzi e cia ltda  73856593000166
# 76300                       prati,donaduzzi e cia ltda  73856593000166
#
#                emit_bairro  emit_municipio  emit_cep   emit_lat  emit_long  \
# 11150             sao jose  campina grande  58400370  -7.224674 -35.877129
# 17878               velame  campina grande  58420450  -7.224674 -35.877129
# 39530               centro       guarabira  58200000  -6.851398 -35.491558
# 47885               centro        timbauba  55870000  -7.511882 -35.316076
# 48046               centro        timbauba  55870000  -7.511882 -35.316076
# 48068               centro        timbauba  55870000  -7.511882 -35.316076
# 48076               centro        timbauba  55870000  -7.511882 -35.316076
# 48185               centro        timbauba  55870000  -7.511882 -35.316076
# 48408               centro        timbauba  55870000  -7.511882 -35.316076
# 48838               centro        timbauba  55870000  -7.511882 -35.316076
# 48981               centro        timbauba  55870000  -7.511882 -35.316076
# 76294  c ind nilton arruda          toledo  85903630 -22.743397 -46.373504
# 76295  c ind nilton arruda          toledo  85903630 -22.743397 -46.373504
# 76296  c ind nilton arruda          toledo  85903630 -22.743397 -46.373504
# 76297  c ind nilton arruda          toledo  85903630 -22.743397 -46.373504
# 76298  c ind nilton arruda          toledo  85903630 -22.743397 -46.373504
# 76299  c ind nilton arruda          toledo  85903630 -22.743397 -46.373504
# 76300  c ind nilton arruda          toledo  85903630 -22.743397 -46.373504
#
#                                                prod_desc  prod_ncm  prod_cfop  \
# 11150          dimeticona 40mg (simeticona) (g) cx c/600  30049099       5904
# 17878                        simeticona 40mg comprimidos  30049099       5403
# 39530                                    simeticona 40mg  30049099       5102
# 47885  simeticona 40mg c/600 comp-(imposto ibpt nacio...  30049099       6403
# 48046  simeticona 40mg c/600 comp-(imposto ibpt nacio...  30049099       6403
# 48068  simeticona 40mg c/600 comp-(imposto ibpt nacio...  30049099       6403
# 48076  simeticona 40mg c/600 comp-(imposto ibpt nacio...  30049099       6403
# 48185  simeticona 40mg c/600 comp-(imposto ibpt nacio...  30049099       2411
# 48408  simeticona 40mg c/600 comp-(imposto ibpt nacio...  30049099       2411
# 48838  simeticona 40mg c/600 comp-(imposto ibpt nacio...  30049099       6403
# 48981  simeticona 40mg c/600 comp-(imposto ibpt nacio...  30049099       6403
# 76294    - simeticona 40mg 30x20 cps-vp / gen dimeticona  30049099       6107
# 76295    - simeticona 40mg 30x20 cps-vp / gen dimeticona  30049099       6107
# 76296    - simeticona 40mg 30x20 cps-vp / gen dimeticona  30049099       6107
# 76297    - simeticona 40mg 30x20 cps-vp / gen dimeticona  30049099       6107
# 76298    - simeticona 40mg 30x20 cps-vp / gen dimeticona  30049099       6107
# 76299    - simeticona 40mg 30x20 cps-vp / gen dimeticona  30049099       6107
# 76300    - simeticona 40mg 30x20 cps-vp / gen dimeticona  30049099       6107
#
#        prod_quant prod_unid  prod_valor_unit  prod_valor_total
# 11150       600.0        cp             0.18             108.0
# 17878       600.0        cp             0.09              54.0
# 39530       600.0        cp             0.08              48.0
# 47885       500.0        cp             0.08              40.0
# 48046       500.0        cp             0.08              40.0
# 48068       600.0        cp             0.13              78.0
# 48076      1000.0        cp             0.13             130.0
# 48185       500.0        cp             0.08              40.0
# 48408       500.0        cp             0.08              40.0
# 48838      1120.0        cp             0.13             145.6
# 48981       500.0        cp             0.13              65.0
# 76294       600.0        cp             0.07              42.0
# 76295      1800.0        cp             0.07             126.0
# 76296      1800.0        cp             0.07             126.0
# 76297      1800.0        cp             0.07             126.0
# 76298     24600.0        cp             0.07            1722.0
# 76299      1800.0        cp             0.07             126.0
# 76300      4800.0        cp             0.07             336.0
